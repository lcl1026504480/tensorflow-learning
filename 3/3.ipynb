# %% [markdown]
# # word2vec

# %%
# %run word2vec_basic.py
# Out:
# Data size 17005207
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']
# 3081 originated -> 5234 anarchism
# 3081 originated -> 12 as
# 12 as -> 6 a
# 12 as -> 3081 originated
# 6 a -> 195 term
# 6 a -> 12 as
# 195 term -> 6 a
# 195 term -> 2 of
# Initialized
# Average loss at step  0 :  285.30926513671875
# Nearest to some: apatosaurus, stationery, vater, heb, akbar, unverified, preferences, honeymoon
# Nearest to will: dme, commercialism, eugene, scans, thirst, mobutu, cooler, jeans
# Nearest to over: cathal, cade, vs, magistracy, fargo, freising, naughty, lutheranism
# Nearest to its: baguirmi, breed, socks, tosk, mogadishu, saville, angeles, ystok
# Nearest to three: fuerza, strontium, malignant, antigen, cytotoxic, tones, embedded, primaries
# ...
